# %%
from translation_stats import translator_language_proficiency_misc_babel_template
translator_language_proficiency_misc_babel_template.generate_csv_files()
# Out:
# Language data saved successfully.
# Number of rows in results for aawiki: 0
# No results found.
# CSV file for aawiki generated successfully.
# Number of rows in results for abwiki: 5
# CSV file for abwiki generated successfully.
# Number of rows in results for acewiki: 14
# CSV file for acewiki generated successfully.
# Number of rows in results for adywiki: 3
# CSV file for adywiki generated successfully.
# Number of rows in results for afwiki: 198
# CSV file for afwiki generated successfully.
# Number of rows in results for akwiki: 2
# CSV file for akwiki generated successfully.
# Number of rows in results for alswiki: 31
# CSV file for alswiki generated successfully.
# Number of rows in results for altwiki: 2
# CSV file for altwiki generated successfully.
# Number of rows in results for amwiki: 60
# CSV file for amwiki generated successfully.
# Number of rows in results for amiwiki: 2
# CSV file for amiwiki generated successfully.
# Number of rows in results for anwiki: 54
# ...

# %%
from translation_stats import translator_language_proficiency_user_template
translator_language_proficiency_user_template.generate_csv_files()
# Out:
# Language data saved successfully.
# Number of rows in results for aawiki: 0
# No results found.
# CSV file for aawiki generated successfully.
# Number of rows in results for abwiki: 5
# CSV file for abwiki generated successfully.
# Number of rows in results for acewiki: 14
# CSV file for acewiki generated successfully.
# Number of rows in results for adywiki: 3
# CSV file for adywiki generated successfully.
# Number of rows in results for afwiki: 198
# CSV file for afwiki generated successfully.
# Number of rows in results for akwiki: 2
# CSV file for akwiki generated successfully.
# Number of rows in results for alswiki: 31
# CSV file for alswiki generated successfully.
# Number of rows in results for altwiki: 2
# CSV file for altwiki generated successfully.
# Number of rows in results for amwiki: 60
# CSV file for amwiki generated successfully.
# Number of rows in results for amiwiki: 2
# CSV file for amiwiki generated successfully.
# Number of rows in results for anwiki: 54
# ...

# %%
from translation_stats import translator_language_proficiency_standard_babel_template
translator_language_proficiency_standard_babel_template.generate_csv_files()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 2
#       1 from translation_stats import translator_language_proficiency_standard_babel_template
# ----> 2 translator_language_proficiency_standard_babel_template.generate_csv_files()
#
# File ~/translation-stats-lib/translation_stats/translator_language_proficiency_standard_babel_template.py:69, in generate_csv_files()
#      66         allowed_languages.append(row['Language Code'])
#      68 for database in dbnames:
# ---> 69     results = fetch_babel_data(database)
#      71     formatted_results = format_language_proficiency(results, allowed_languages)
#      73     output_filename = f"/home/paws/translation-stats-data/translator_language_proficiency_standard_babel/{database}_translator_language_proficiency_standard_babel.csv"
#
# ...
