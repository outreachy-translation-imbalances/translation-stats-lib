# %% [markdown]
# Generate language proficiency for translators from standard babel template

# %%
from translation_stats import translator_language_proficiency_standard_babel_template
translator_language_proficiency_standard_babel_template.generate_csv_files()
# Out:
# Empty CSV file created: /home/paws/translation-stats-data/translator_language_proficiency_standard_babel/aawiki_translator_language_proficiency_standard_babel.csv
# CSV file saved: /home/paws/translation-stats-data/translator_language_proficiency_standard_babel/aawiki_translator_language_proficiency_standard_babel.csv
# CSV file saved: /home/paws/translation-stats-data/translator_language_proficiency_standard_babel/abwiki_translator_language_proficiency_standard_babel.csv
# CSV file saved: /home/paws/translation-stats-data/translator_language_proficiency_standard_babel/acewiki_translator_language_proficiency_standard_babel.csv
# CSV file saved: /home/paws/translation-stats-data/translator_language_proficiency_standard_babel/adywiki_translator_language_proficiency_standard_babel.csv
# CSV file saved: /home/paws/translation-stats-data/translator_language_proficiency_standard_babel/afwiki_translator_language_proficiency_standard_babel.csv
# ...

# %% [markdown]
# Generate the revision tables for each of the different language wikipedia versions

# %%
from translation_stats import revision_table
revision_table.generate_csv_files()
# Out:
# No results found.
# CSV file generated successfully: /home/paws/translation-stats-data/revision_table/aawiki_revision_table.csv
# CSV file generated successfully: /home/paws/translation-stats-data/revision_table/abwiki_revision_table.csv
# CSV file generated successfully: /home/paws/translation-stats-data/revision_table/acewiki_revision_table.csv
# CSV file generated successfully: /home/paws/translation-stats-data/revision_table/adywiki_revision_table.csv
# CSV file generated successfully: /home/paws/translation-stats-data/revision_table/afwiki_revision_table.csv
# CSV file generated successfully: /home/paws/translation-stats-data/revision_table/akwiki_revision_table.csv
# CSV file generated successfully: /home/paws/translation-stats-data/revision_table/alswiki_revision_table.csv
# CSV file generated successfully: /home/paws/translation-stats-data/revision_table/altwiki_revision_table.csv
# ...
